# %%
import numpy as np
import tensorflow as tf
import os
from keras import regularizers
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D,AveragePooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
import cv2
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D,ZeroPadding2D,AveragePooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.layers import Input,add
from keras.models import Model
from keras.layers import concatenate 
from keras.layers import GlobalAveragePooling2D
# Out:
# Using TensorFlow backend.

# %%
#loading dataset
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
def get_cutout_eraser_and_random_crop(p=0.5,s_l=0.05,s_h=0.3,r_1=0.3,r_2=1/0.3,max_erasers_per_image=1,pixel_level=True,random_crop_size=(32,32),padding_pixels=4):
  
  assert max_erasers_per_image>=1 
  def eraser(input_img):
        v_l = np.min(input_img)
        v_h = np.max(input_img)
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img
        mx = np.random.randint(1,max_erasers_per_image+1)
        for i in range(mx):
          while True:
              s = np.random.uniform(s_l, s_h) * img_h * img_w
              r = np.random.uniform(r_1, r_2)
              w = int(np.sqrt(s / r))
              h = int(np.sqrt(s * r))
              left = np.random.randint(0, img_w)
              top = np.random.randint(0, img_h)

              if left + w <= img_w and top + h <= img_h:
                  break

          if pixel_level:
              c = np.random.uniform(v_l, v_h, (h, w, img_c))
          else:
              c = np.random.uniform(v_l, v_h)

          input_img[top:top + h, left:left + w, :] = c
        return input_img

    
  def random_crop(input_image):
    assert input_image.shape[2]==3

    #pad for 4 pixels
    img = cv2.copyMakeBorder(input_image,padding_pixels,padding_pixels,padding_pixels,padding_pixels,cv2.BORDER_REPLICATE)
    height , width =img.shape[0],img.shape[1]
    dy,dx = random_crop_size
    x = np.random.randint(0,width - dx + 1)
    y = np.random.randint(0,height - dy + 1)
    return img[y:(y+dy),x:(x+dx),:]

  def preprocess_image(input_image):
    return eraser(random_crop(input_image))
  
  return preprocess_image

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

datagen = ImageDataGenerator(horizontal_flip=0.5,preprocessing_function=get_cutout_eraser_and_random_crop())
test_datagen = ImageDataGenerator(horizontal_flip=True,vertical_flip=True)
test_datagen.fit(train_features)

# %%
datagen.mean = np.array([0.4914, 0.4822, 0.4465], dtype=np.float32).reshape((1,1,3)) # ordering: [R, G, B]
datagen.std = np.array([0.2023, 0.1994, 0.2010], dtype=np.float32).reshape((1,1,3)) # ordering: [R, G, B

# %% [markdown]
# #Resnet Model Creation

# %%
def ResNetBlock(input_layer, channels,stride=1):
  
  bn_1 = BatchNormalization()(input_layer)
  activation_layer_b1 = Activation('relu')(bn_1)
  block_layer_1 = Convolution2D(channels, (3,3), padding='same',strides=stride)(activation_layer_b1)
  
  bn_2 = BatchNormalization()(block_layer_1)
  activation_layer_b2 = Activation('relu')(bn_2) 
  block_layer_2 = Convolution2D(channels, (3,3), padding='same')(activation_layer_b2)
   
  
  return block_layer_2

# %%
from keras.layers import Input, add, GlobalAveragePooling2D, Dense
from keras.models import Model

inputs =Input(shape=(32, 32, 3))

x1 = Convolution2D(64, (3, 3),padding='same')(inputs)   #32x32 
activation_x1 = Activation('relu')(x1)

x2 = Convolution2D(64, (3, 3),padding='same')(activation_x1)   #32x32 
activation_x2 = Activation('relu')(x2)

x3 = Convolution2D(64, (3, 3),padding='same')(activation_x2)   #32x32 
activation_x3 = Activation('relu')(x3)


##block 1

blk1 = ResNetBlock(activation_x3,64)  ##32x32
z1 = add([blk1,activation_x3])

blk1_c = ResNetBlock(z1,64)
z1_c = add([blk1_c,z1])

##block 2

blk2 = ResNetBlock(z1_c,128)
one_blk = Convolution2D(128, (1, 1), padding='same')(z1_c)
z2 = add([blk2,one_blk])

blk2_c = ResNetBlock(z2,128)
z2_c = add([blk2_c,z2])

##block3

blk3 = ResNetBlock(z2_c,128,stride=2)
one_blk_1 = Convolution2D(128, (1, 1), padding='same',strides=2)(z2_c)
z3 = add([blk3,one_blk_1])

blk3_c = ResNetBlock(z3,128)
z3_c = add([blk3_c,z3])

##block4

blk4 = ResNetBlock(z3_c,256,stride=2)
one_blk_2 = Convolution2D(256, (1, 1), padding='same',strides=2)(z3_c)
z4 = add([blk4,one_blk_2])

blk4_c = ResNetBlock(z4,256)
z4_c = add([blk4_c,z4])

avg_pool_layer = GlobalAveragePooling2D()(z4_c)

#flatten_layer = Flatten()(avg_pool_layer)

fc_layer = Dense(10, activation='softmax')(avg_pool_layer)


model = Model(inputs=inputs, outputs= fc_layer)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0803 21:56:47.372532 140138222847872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0803 21:56:47.410990 140138222847872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0803 21:56:47.419080 140138222847872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0803 21:56:47.480641 140138222847872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0803 21:56:47.481405 140138222847872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0803 21:56:50.154198 140138222847872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         activation_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           conv2d_5[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           conv2d_7[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 128)  73856       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  147584      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 128)  8320        add_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 128)  0           conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 128)  512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 128)  0           conv2d_12[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 128)  512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  16512       add_4[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 128)  0           conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 128)  512         add_5[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 128)  147584      activation_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 128)  0           conv2d_17[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 128)  512         add_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    295168      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 256)    1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 256)    33024       add_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 256)    0           conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 256)    1024        add_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 256)    590080      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 256)    590080      activation_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 256)    0           conv2d_22[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           add_8[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           2570        global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 3,464,586
# Trainable params: 3,460,362
# Non-trainable params: 4,224
# __________________________________________________________________________________________________

# %%
from keras.optimizers import SGD
opt = SGD(lr=0.001,  decay=5e-4)
model.compile(optimizer=opt , loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# W0803 21:56:51.672415 140138222847872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
##normalization part is remaining :::

# %% [markdown]
# #LR finder

# %%
class LRFinder(Callback):
    def __init__(self,
                 num_samples,
                 batch_size,
                 minimum_lr=1e-5,
                 maximum_lr=10.,
                 lr_scale='exp',
                 validation_data=None,
                 validation_sample_rate=5,
                 stopping_criterion_factor=4.,
                 loss_smoothing_beta=0.98,
                 save_dir=None,
                 verbose=True):
        
        super(LRFinder, self).__init__()

        if lr_scale not in ['exp', 'linear']:
            raise ValueError("`lr_scale` must be one of ['exp', 'linear']")

        if validation_data is not None:
            self.validation_data = validation_data
            self.use_validation_set = True

            if validation_sample_rate > 0 or validation_sample_rate < 0:
                self.validation_sample_rate = validation_sample_rate
            else:
                raise ValueError("`validation_sample_rate` must be a positive or negative integer other than o")
        else:
            self.use_validation_set = False
            self.validation_sample_rate = 0

        self.num_samples = num_samples
        self.batch_size = batch_size
        self.initial_lr = minimum_lr
        self.final_lr = maximum_lr
        self.lr_scale = lr_scale
        self.stopping_criterion_factor = stopping_criterion_factor
        self.loss_smoothing_beta = loss_smoothing_beta
        self.save_dir = save_dir
        self.verbose = verbose

        self.num_batches_ = num_samples // batch_size
        self.current_lr_ = minimum_lr

        if lr_scale == 'exp':
            self.lr_multiplier_ = (maximum_lr / float(minimum_lr)) ** (
                1. / float(self.num_batches_))
        else:
            extra_batch = int((num_samples % batch_size) != 0)
            self.lr_multiplier_ = np.linspace(
                minimum_lr, maximum_lr, num=self.num_batches_ + extra_batch)

        # If negative, use entire validation set
        if self.validation_sample_rate < 0:
            self.validation_sample_rate = self.validation_data[0].shape[0] // batch_size

        self.current_batch_ = 0
        self.current_epoch_ = 0
        self.best_loss_ = 1e6
        self.running_loss_ = 0.

        self.history = {}

    def on_train_begin(self, logs=None):

        self.current_epoch_ = 1
        K.set_value(self.model.optimizer.lr, self.initial_lr)

        warnings.simplefilter("ignore")

    def on_epoch_begin(self, epoch, logs=None):
        self.current_batch_ = 0

        if self.current_epoch_ > 1:
            warnings.warn(
                "\n\nLearning rate finder should be used only with a single epoch. "
                "Hereafter, the callback will not measure the losses.\n\n")

    def on_batch_begin(self, batch, logs=None):
        self.current_batch_ += 1

    def on_batch_end(self, batch, logs=None):
        if self.current_epoch_ > 1:
            return

        if self.use_validation_set:
            X, Y = self.validation_data[0], self.validation_data[1]

            # use 5 random batches from test set for fast approximate of loss
            num_samples = self.batch_size * self.validation_sample_rate

            if num_samples > X.shape[0]:
                num_samples = X.shape[0]

            idx = np.random.choice(X.shape[0], num_samples, replace=False)
            x = X[idx]
            y = Y[idx]

            values = self.model.evaluate(x, y, batch_size=self.batch_size, verbose=False)
            loss = values[0]
        else:
            loss = logs['loss']

        # smooth the loss value and bias correct
        running_loss = self.loss_smoothing_beta * loss + (
            1. - self.loss_smoothing_beta) * loss
        running_loss = running_loss / (
            1. - self.loss_smoothing_beta**self.current_batch_)

        # stop logging if loss is too large
        if self.current_batch_ > 1 and self.stopping_criterion_factor is not None and (
                running_loss >
                self.stopping_criterion_factor * self.best_loss_):

            if self.verbose:
                print(" - LRFinder: Skipping iteration since loss is %d times as large as best loss (%0.4f)"
                      % (self.stopping_criterion_factor, self.best_loss_))
            return

        if running_loss < self.best_loss_ or self.current_batch_ == 1:
            self.best_loss_ = running_loss

        current_lr = K.get_value(self.model.optimizer.lr)

        self.history.setdefault('running_loss_', []).append(running_loss)
        if self.lr_scale == 'exp':
            self.history.setdefault('log_lrs', []).append(np.log10(current_lr))
        else:
            self.history.setdefault('log_lrs', []).append(current_lr)

        # compute the lr for the next batch and update the optimizer lr
        if self.lr_scale == 'exp':
            current_lr *= self.lr_multiplier_
        else:
            current_lr = self.lr_multiplier_[self.current_batch_ - 1]

        K.set_value(self.model.optimizer.lr, current_lr)

        # save the other metrics as well
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

        if self.verbose:
            if self.use_validation_set:
                print(" - LRFinder: val_loss: %1.4f - lr = %1.8f " %
                      (values[0], current_lr))
            else:
                print(" - LRFinder: lr = %1.8f " % current_lr)

    def on_epoch_end(self, epoch, logs=None):
        if self.save_dir is not None and self.current_epoch_ <= 1:
            if not os.path.exists(self.save_dir):
                os.makedirs(self.save_dir)

            losses_path = os.path.join(self.save_dir, 'losses.npy')
            lrs_path = os.path.join(self.save_dir, 'lrs.npy')

            np.save(losses_path, self.losses)
            np.save(lrs_path, self.lrs)

            if self.verbose:
                print("\tLR Finder : Saved the losses and learning rate values in path : {%s}"
                      % (self.save_dir))

        self.current_epoch_ += 1

        warnings.simplefilter("default")

    def plot_schedule(self, clip_beginning=None, clip_endding=None):
        """
        Plots the schedule from the callback itself.
        # Arguments:
            clip_beginning: Integer or None. If positive integer, it will
                remove the specified portion of the loss graph to remove the large
                loss values in the beginning of the graph.
            clip_endding: Integer or None. If negative integer, it will
                remove the specified portion of the ending of the loss graph to
                remove the sharp increase in the loss values at high learning rates.
        """
        try:
            import matplotlib.pyplot as plt
            plt.style.use('seaborn-white')
        except ImportError:
            print(
                "Matplotlib not found. Please use `pip install matplotlib` first."
            )
            return

        if clip_beginning is not None and clip_beginning < 0:
            clip_beginning = -clip_beginning

        if clip_endding is not None and clip_endding > 0:
            clip_endding = -clip_endding

        losses = self.losses
        lrs = self.lrs

        if clip_beginning:
            losses = losses[clip_beginning:]
            lrs = lrs[clip_beginning:]

        if clip_endding:
            losses = losses[:clip_endding]
            lrs = lrs[:clip_endding]

        plt.plot(lrs, losses)
        plt.title('Learning rate vs Loss')
        plt.xlabel('learning rate')
        plt.ylabel('loss')
        plt.show()

    @classmethod
    def restore_schedule_from_dir(cls,
                                  directory,
                                  clip_beginning=None,
                                  clip_endding=None):
        """
        Loads the training history from the saved numpy files in the given directory.
        # Arguments:
            directory: String. Path to the directory where the serialized numpy
                arrays of the loss and learning rates are saved.
            clip_beginning: Integer or None. If positive integer, it will
                remove the specified portion of the loss graph to remove the large
                loss values in the beginning of the graph.
            clip_endding: Integer or None. If negative integer, it will
                remove the specified portion of the ending of the loss graph to
                remove the sharp increase in the loss values at high learning rates.
        Returns:
            tuple of (losses, learning rates)
        """
        if clip_beginning is not None and clip_beginning < 0:
            clip_beginning = -clip_beginning

        if clip_endding is not None and clip_endding > 0:
            clip_endding = -clip_endding

        losses_path = os.path.join(directory, 'losses.npy')
        lrs_path = os.path.join(directory, 'lrs.npy')

        if not os.path.exists(losses_path) or not os.path.exists(lrs_path):
            print("%s and %s could not be found at directory : {%s}" %
                  (losses_path, lrs_path, directory))

            losses = None
            lrs = None

        else:
            losses = np.load(losses_path)
            lrs = np.load(lrs_path)

            if clip_beginning:
                losses = losses[clip_beginning:]
                lrs = lrs[clip_beginning:]

            if clip_endding:
                losses = losses[:clip_endding]
                lrs = lrs[:clip_endding]

        return losses, lrs

    @classmethod
    def plot_schedule_from_file(cls,
                                directory,
                                clip_beginning=None,
                                clip_endding=None):
        """
        Plots the schedule from the saved numpy arrays of the loss and learning
        rate values in the specified directory.
        # Arguments:
            directory: String. Path to the directory where the serialized numpy
                arrays of the loss and learning rates are saved.
            clip_beginning: Integer or None. If positive integer, it will
                remove the specified portion of the loss graph to remove the large
                loss values in the beginning of the graph.
            clip_endding: Integer or None. If negative integer, it will
                remove the specified portion of the ending of the loss graph to
                remove the sharp increase in the loss values at high learning rates.
        """
        try:
            import matplotlib.pyplot as plt
            plt.style.use('seaborn-white')
        except ImportError:
            print("Matplotlib not found. Please use `pip install matplotlib` first.")
            return

        losses, lrs = cls.restore_schedule_from_dir(
            directory,
            clip_beginning=clip_beginning,
            clip_endding=clip_endding)

        if losses is None or lrs is None:
            return
        else:
            plt.plot(lrs, losses)
            plt.title('Learning rate vs Loss')
            plt.xlabel('learning rate')
            plt.ylabel('loss')
            plt.show()

    @property
    def lrs(self):
        return np.array(self.history['log_lrs'])

    @property
    def losses(self):
        return np.array(self.history['running_loss_'])

# %%
train_features.shape
# Out:
# (50000, 32, 32, 3)

# %%
from keras.callbacks import Callback
import os
import keras.backend as K
import warnings
from lr_finder import LRFinder

lrf = LRFinder(model)
generator = datagen.flow(train_features, train_labels , batch_size=256,shuffle=True)
test_generator = test_datagen.flow(test_features,test_labels , batch_size=256, shuffle=True)
lrf.find_generator(generator, 0.0001, 10.0,test_generator, epochs=1, steps_per_epoch=None,)
lrf.plot_loss()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-f6c31e35ae47> in <module>()
#       3 import keras.backend as K
#       4 import warnings
# ----> 5 from lr_finder import LRFinder
#       6
#       7 lrf = LRFinder(model)
#
# ModuleNotFoundError: No module named 'lr_finder'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# #LR =  0.005

# %%
#from one_cycle_lr import LRFinder
from one_cycle_lr import LRFinder
num_samples= train_features.shape[0]
batch_size = 128
num_epoch=50
max_lr=0.005

# %% [markdown]
# #Best LR would be 0.005

# %%
opt = SGD(lr=0.005,  decay=5e-4)
model.compile(optimizer=opt , loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from one_cycle_lr import OneCycleLR

lr_manager = OneCycleLR(num_samples, num_epoch, batch_size, max_lr,
                        end_percentage=0.1, scale_percentage=None,
                        maximum_momentum=0.95, minimum_momentum=0.85)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
filepath = "/content/gdrive/My Drive/Resnet-13.hdf5"


checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')


# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 300, 
                                 validation_data = (test_features, test_labels), verbose=1,callbacks=[checkpoint,lr_manager])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=300)`
#   # Remove the CWD from sys.path while we load stuff.
# W0803 21:58:55.107412 140138222847872 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/300
# 390/390 [==============================] - 90s 230ms/step - loss: 1.7819 - acc: 0.3456 - val_loss: 1.7108 - val_acc: 0.3950
#
# Epoch 00001: val_acc improved from -inf to 0.39500, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00070 - momentum: 0.95
# Epoch 2/300
# 390/390 [==============================] - 86s 219ms/step - loss: 1.4827 - acc: 0.4584 - val_loss: 2.1809 - val_acc: 0.3436
#
# Epoch 00002: val_acc did not improve from 0.39500
#  - lr: 0.00090 - momentum: 0.94
# Epoch 3/300
# 390/390 [==============================] - 85s 217ms/step - loss: 1.3334 - acc: 0.5171 - val_loss: 2.0811 - val_acc: 0.4044
#
# Epoch 00003: val_acc improved from 0.39500 to 0.40440, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00110 - momentum: 0.94
# Epoch 4/300
# 390/390 [==============================] - 85s 217ms/step - loss: 1.2289 - acc: 0.5605 - val_loss: 2.4481 - val_acc: 0.3972
#
# Epoch 00004: val_acc did not improve from 0.40440
#  - lr: 0.00130 - momentum: 0.93
# Epoch 5/300
# 390/390 [==============================] - 85s 218ms/step - loss: 1.1287 - acc: 0.5977 - val_loss: 3.2496 - val_acc: 0.3866
#
# Epoch 00005: val_acc did not improve from 0.40440
#  - lr: 0.00150 - momentum: 0.93
# Epoch 6/300
# 390/390 [==============================] - 85s 218ms/step - loss: 1.0419 - acc: 0.6303 - val_loss: 1.3671 - val_acc: 0.5485
#
# Epoch 00006: val_acc improved from 0.40440 to 0.54850, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00170 - momentum: 0.92
# Epoch 7/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.9755 - acc: 0.6550 - val_loss: 1.1566 - val_acc: 0.6190
#
# Epoch 00007: val_acc improved from 0.54850 to 0.61900, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00190 - momentum: 0.92
# Epoch 8/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.9246 - acc: 0.6728 - val_loss: 1.8291 - val_acc: 0.5247
#
# Epoch 00008: val_acc did not improve from 0.61900
#  - lr: 0.00210 - momentum: 0.91
# Epoch 9/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.8785 - acc: 0.6902 - val_loss: 1.1117 - val_acc: 0.6563
#
# Epoch 00009: val_acc improved from 0.61900 to 0.65630, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00230 - momentum: 0.91
# Epoch 10/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.8393 - acc: 0.7039 - val_loss: 1.4363 - val_acc: 0.5436
#
# Epoch 00010: val_acc did not improve from 0.65630
#  - lr: 0.00250 - momentum: 0.91
# Epoch 11/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.8027 - acc: 0.7175 - val_loss: 0.9619 - val_acc: 0.6743
#
# Epoch 00011: val_acc improved from 0.65630 to 0.67430, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00270 - momentum: 0.90
# Epoch 12/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.7796 - acc: 0.7270 - val_loss: 0.8347 - val_acc: 0.7084
#
# Epoch 00012: val_acc improved from 0.67430 to 0.70840, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00290 - momentum: 0.90
# Epoch 13/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.7496 - acc: 0.7380 - val_loss: 1.1142 - val_acc: 0.6517
#
# Epoch 00013: val_acc did not improve from 0.70840
#  - lr: 0.00310 - momentum: 0.89
# Epoch 14/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.7239 - acc: 0.7454 - val_loss: 0.9893 - val_acc: 0.6919
#
# Epoch 00014: val_acc did not improve from 0.70840
#  - lr: 0.00330 - momentum: 0.89
# Epoch 15/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.6979 - acc: 0.7560 - val_loss: 1.1722 - val_acc: 0.6509
#
# Epoch 00015: val_acc did not improve from 0.70840
#  - lr: 0.00350 - momentum: 0.88
# Epoch 16/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.6786 - acc: 0.7645 - val_loss: 0.9299 - val_acc: 0.6805
#
# Epoch 00016: val_acc did not improve from 0.70840
#  - lr: 0.00370 - momentum: 0.88
# Epoch 17/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.6636 - acc: 0.7693 - val_loss: 0.8685 - val_acc: 0.7172
#
# Epoch 00017: val_acc improved from 0.70840 to 0.71720, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00390 - momentum: 0.87
# Epoch 18/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.6409 - acc: 0.7766 - val_loss: 0.8743 - val_acc: 0.7241
#
# Epoch 00018: val_acc improved from 0.71720 to 0.72410, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00410 - momentum: 0.87
# Epoch 19/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.6271 - acc: 0.7816 - val_loss: 0.6942 - val_acc: 0.7706
#
# Epoch 00019: val_acc improved from 0.72410 to 0.77060, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00430 - momentum: 0.87
# Epoch 20/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.6147 - acc: 0.7862 - val_loss: 0.6485 - val_acc: 0.7797
#
# Epoch 00020: val_acc improved from 0.77060 to 0.77970, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00450 - momentum: 0.86
# Epoch 21/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.5985 - acc: 0.7929 - val_loss: 0.6890 - val_acc: 0.7733
#
# Epoch 00021: val_acc did not improve from 0.77970
#  - lr: 0.00470 - momentum: 0.86
# Epoch 22/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.5852 - acc: 0.7950 - val_loss: 0.7585 - val_acc: 0.7620
#
# Epoch 00022: val_acc did not improve from 0.77970
#  - lr: 0.00490 - momentum: 0.85
# Epoch 23/300
# 390/390 [==============================] - 84s 217ms/step - loss: 0.5816 - acc: 0.7972 - val_loss: 0.7223 - val_acc: 0.7614
#
# Epoch 00023: val_acc did not improve from 0.77970
#  - lr: 0.00490 - momentum: 0.85
# Epoch 24/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.5615 - acc: 0.8046 - val_loss: 0.8819 - val_acc: 0.7257
#
# Epoch 00024: val_acc did not improve from 0.77970
#  - lr: 0.00470 - momentum: 0.86
# Epoch 25/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.5502 - acc: 0.8087 - val_loss: 0.7252 - val_acc: 0.7673
#
# Epoch 00025: val_acc did not improve from 0.77970
#  - lr: 0.00450 - momentum: 0.86
# Epoch 26/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.5395 - acc: 0.8135 - val_loss: 0.5876 - val_acc: 0.8057
#
# Epoch 00026: val_acc improved from 0.77970 to 0.80570, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00430 - momentum: 0.87
# Epoch 27/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.5246 - acc: 0.8196 - val_loss: 0.7016 - val_acc: 0.7770
#
# Epoch 00027: val_acc did not improve from 0.80570
#  - lr: 0.00410 - momentum: 0.87
# Epoch 28/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.5211 - acc: 0.8177 - val_loss: 0.6250 - val_acc: 0.8077
#
# Epoch 00028: val_acc improved from 0.80570 to 0.80770, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00390 - momentum: 0.87
# Epoch 29/300
# 390/390 [==============================] - 84s 217ms/step - loss: 0.5088 - acc: 0.8218 - val_loss: 0.5728 - val_acc: 0.8095
#
# Epoch 00029: val_acc improved from 0.80770 to 0.80950, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00370 - momentum: 0.88
# Epoch 30/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.4980 - acc: 0.8262 - val_loss: 0.5001 - val_acc: 0.8304
#
# Epoch 00030: val_acc improved from 0.80950 to 0.83040, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00350 - momentum: 0.88
# Epoch 31/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.4911 - acc: 0.8282 - val_loss: 0.5735 - val_acc: 0.8141
#
# Epoch 00031: val_acc did not improve from 0.83040
#  - lr: 0.00330 - momentum: 0.89
# Epoch 32/300
# 390/390 [==============================] - 84s 217ms/step - loss: 0.4846 - acc: 0.8327 - val_loss: 0.5547 - val_acc: 0.8194
#
# Epoch 00032: val_acc did not improve from 0.83040
#  - lr: 0.00310 - momentum: 0.89
# Epoch 33/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.4797 - acc: 0.8329 - val_loss: 0.5915 - val_acc: 0.8150
#
# Epoch 00033: val_acc did not improve from 0.83040
#  - lr: 0.00290 - momentum: 0.90
# Epoch 34/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.4683 - acc: 0.8376 - val_loss: 0.5199 - val_acc: 0.8236
#
# Epoch 00034: val_acc did not improve from 0.83040
#  - lr: 0.00270 - momentum: 0.90
# Epoch 35/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.4633 - acc: 0.8386 - val_loss: 0.5697 - val_acc: 0.8105
#
# Epoch 00035: val_acc did not improve from 0.83040
#  - lr: 0.00250 - momentum: 0.91
# Epoch 36/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.4527 - acc: 0.8424 - val_loss: 0.5575 - val_acc: 0.8186
#
# Epoch 00036: val_acc did not improve from 0.83040
#  - lr: 0.00230 - momentum: 0.91
# Epoch 37/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.4456 - acc: 0.8454 - val_loss: 0.5129 - val_acc: 0.8319
#
# Epoch 00037: val_acc improved from 0.83040 to 0.83190, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00210 - momentum: 0.91
# Epoch 38/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.4412 - acc: 0.8479 - val_loss: 0.4990 - val_acc: 0.8357
#
# Epoch 00038: val_acc improved from 0.83190 to 0.83570, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00190 - momentum: 0.92
# Epoch 39/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.4361 - acc: 0.8476 - val_loss: 0.6081 - val_acc: 0.8064
#
# Epoch 00039: val_acc did not improve from 0.83570
#  - lr: 0.00170 - momentum: 0.92
# Epoch 40/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.4330 - acc: 0.8488 - val_loss: 0.4917 - val_acc: 0.8374
#
# Epoch 00040: val_acc improved from 0.83570 to 0.83740, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00150 - momentum: 0.93
# Epoch 41/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.4252 - acc: 0.8513 - val_loss: 0.4952 - val_acc: 0.8348
#
# Epoch 00041: val_acc did not improve from 0.83740
#  - lr: 0.00130 - momentum: 0.93
# Epoch 42/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.4141 - acc: 0.8563 - val_loss: 0.4378 - val_acc: 0.8551
#
# Epoch 00042: val_acc improved from 0.83740 to 0.85510, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00110 - momentum: 0.94
# Epoch 43/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.4127 - acc: 0.8567 - val_loss: 0.4585 - val_acc: 0.8494
#
# Epoch 00043: val_acc did not improve from 0.85510
#  - lr: 0.00090 - momentum: 0.94
# Epoch 44/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.4078 - acc: 0.8595 - val_loss: 0.4865 - val_acc: 0.8469
#
# Epoch 00044: val_acc did not improve from 0.85510
#  - lr: 0.00070 - momentum: 0.95
# Epoch 45/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.4005 - acc: 0.8598 - val_loss: 0.4438 - val_acc: 0.8547
#
# Epoch 00045: val_acc did not improve from 0.85510
#  - lr: 0.00050 - momentum: 0.95
# Epoch 46/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3986 - acc: 0.8625 - val_loss: 0.4511 - val_acc: 0.8549
#
# Epoch 00046: val_acc did not improve from 0.85510
#  - lr: 0.00040 - momentum: 0.95
# Epoch 47/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3938 - acc: 0.8631 - val_loss: 0.4288 - val_acc: 0.8589
#
# Epoch 00047: val_acc improved from 0.85510 to 0.85890, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00030 - momentum: 0.95
# Epoch 48/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3879 - acc: 0.8659 - val_loss: 0.4206 - val_acc: 0.8613
#
# Epoch 00048: val_acc improved from 0.85890 to 0.86130, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00020 - momentum: 0.95
# Epoch 49/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3882 - acc: 0.8654 - val_loss: 0.4260 - val_acc: 0.8574
#
# Epoch 00049: val_acc did not improve from 0.86130
#  - lr: 0.00010 - momentum: 0.95
# Epoch 50/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3884 - acc: 0.8655 - val_loss: 0.4155 - val_acc: 0.8619
#
# Epoch 00050: val_acc improved from 0.86130 to 0.86190, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00001 - momentum: 0.95
# Epoch 51/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3937 - acc: 0.8630 - val_loss: 0.4502 - val_acc: 0.8541
#
# Epoch 00051: val_acc did not improve from 0.86190
#  - lr: 0.00070 - momentum: 0.95
# Epoch 52/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3907 - acc: 0.8640 - val_loss: 0.4677 - val_acc: 0.8479
#
# Epoch 00052: val_acc did not improve from 0.86190
#  - lr: 0.00090 - momentum: 0.94
# Epoch 53/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3930 - acc: 0.8631 - val_loss: 0.5199 - val_acc: 0.8380
#
# Epoch 00053: val_acc did not improve from 0.86190
#  - lr: 0.00110 - momentum: 0.94
# Epoch 54/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3983 - acc: 0.8612 - val_loss: 0.5357 - val_acc: 0.8321
#
# Epoch 00054: val_acc did not improve from 0.86190
#  - lr: 0.00130 - momentum: 0.93
# Epoch 55/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3941 - acc: 0.8642 - val_loss: 0.4815 - val_acc: 0.8391
#
# Epoch 00055: val_acc did not improve from 0.86190
#  - lr: 0.00150 - momentum: 0.93
# Epoch 56/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3989 - acc: 0.8597 - val_loss: 0.5235 - val_acc: 0.8345
#
# Epoch 00056: val_acc did not improve from 0.86190
#  - lr: 0.00170 - momentum: 0.92
# Epoch 57/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3935 - acc: 0.8626 - val_loss: 0.4999 - val_acc: 0.8377
#
# Epoch 00057: val_acc did not improve from 0.86190
#  - lr: 0.00190 - momentum: 0.92
# Epoch 58/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3928 - acc: 0.8641 - val_loss: 0.4758 - val_acc: 0.8459
#
# Epoch 00058: val_acc did not improve from 0.86190
#  - lr: 0.00210 - momentum: 0.91
# Epoch 59/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3940 - acc: 0.8616 - val_loss: 0.5293 - val_acc: 0.8386
#
# Epoch 00059: val_acc did not improve from 0.86190
#  - lr: 0.00230 - momentum: 0.91
# Epoch 60/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3862 - acc: 0.8648 - val_loss: 0.5260 - val_acc: 0.8359
#
# Epoch 00060: val_acc did not improve from 0.86190
#  - lr: 0.00250 - momentum: 0.91
# Epoch 61/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3915 - acc: 0.8641 - val_loss: 0.4899 - val_acc: 0.8411
#
# Epoch 00061: val_acc did not improve from 0.86190
#  - lr: 0.00270 - momentum: 0.90
# Epoch 62/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3858 - acc: 0.8656 - val_loss: 0.4996 - val_acc: 0.8391
#
# Epoch 00062: val_acc did not improve from 0.86190
#  - lr: 0.00290 - momentum: 0.90
# Epoch 63/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3842 - acc: 0.8657 - val_loss: 0.4694 - val_acc: 0.8479
#
# Epoch 00063: val_acc did not improve from 0.86190
#  - lr: 0.00310 - momentum: 0.89
# Epoch 64/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3806 - acc: 0.8675 - val_loss: 0.5459 - val_acc: 0.8319
#
# Epoch 00064: val_acc did not improve from 0.86190
#  - lr: 0.00330 - momentum: 0.89
# Epoch 65/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3806 - acc: 0.8672 - val_loss: 0.5376 - val_acc: 0.8330
#
# Epoch 00065: val_acc did not improve from 0.86190
#  - lr: 0.00350 - momentum: 0.88
# Epoch 66/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3747 - acc: 0.8690 - val_loss: 0.4818 - val_acc: 0.8459
#
# Epoch 00066: val_acc did not improve from 0.86190
#  - lr: 0.00370 - momentum: 0.88
# Epoch 67/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3764 - acc: 0.8684 - val_loss: 0.4720 - val_acc: 0.8439
#
# Epoch 00067: val_acc did not improve from 0.86190
#  - lr: 0.00390 - momentum: 0.87
# Epoch 68/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3740 - acc: 0.8690 - val_loss: 0.4894 - val_acc: 0.8408
#
# Epoch 00068: val_acc did not improve from 0.86190
#  - lr: 0.00410 - momentum: 0.87
# Epoch 69/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3721 - acc: 0.8698 - val_loss: 0.4697 - val_acc: 0.8429
#
# Epoch 00069: val_acc did not improve from 0.86190
#  - lr: 0.00430 - momentum: 0.87
# Epoch 70/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3704 - acc: 0.8712 - val_loss: 0.5556 - val_acc: 0.8238
#
# Epoch 00070: val_acc did not improve from 0.86190
#  - lr: 0.00450 - momentum: 0.86
# Epoch 71/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3682 - acc: 0.8717 - val_loss: 0.5326 - val_acc: 0.8295
#
# Epoch 00071: val_acc did not improve from 0.86190
#  - lr: 0.00470 - momentum: 0.86
# Epoch 72/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3689 - acc: 0.8713 - val_loss: 0.5309 - val_acc: 0.8331
#
# Epoch 00072: val_acc did not improve from 0.86190
#  - lr: 0.00490 - momentum: 0.85
# Epoch 73/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3599 - acc: 0.8725 - val_loss: 0.4747 - val_acc: 0.8457
#
# Epoch 00073: val_acc did not improve from 0.86190
#  - lr: 0.00490 - momentum: 0.85
# Epoch 74/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3582 - acc: 0.8743 - val_loss: 0.4611 - val_acc: 0.8539
#
# Epoch 00074: val_acc did not improve from 0.86190
#  - lr: 0.00470 - momentum: 0.86
# Epoch 75/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3563 - acc: 0.8757 - val_loss: 0.5659 - val_acc: 0.8269
#
# Epoch 00075: val_acc did not improve from 0.86190
#  - lr: 0.00450 - momentum: 0.86
# Epoch 76/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3570 - acc: 0.8751 - val_loss: 0.5430 - val_acc: 0.8371
#
# Epoch 00076: val_acc did not improve from 0.86190
#  - lr: 0.00430 - momentum: 0.87
# Epoch 77/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3479 - acc: 0.8803 - val_loss: 0.4481 - val_acc: 0.8601
#
# Epoch 00077: val_acc did not improve from 0.86190
#  - lr: 0.00410 - momentum: 0.87
# Epoch 78/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3448 - acc: 0.8794 - val_loss: 0.5029 - val_acc: 0.8498
#
# Epoch 00078: val_acc did not improve from 0.86190
#  - lr: 0.00390 - momentum: 0.87
# Epoch 79/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3476 - acc: 0.8794 - val_loss: 0.4706 - val_acc: 0.8503
#
# Epoch 00079: val_acc did not improve from 0.86190
#  - lr: 0.00370 - momentum: 0.88
# Epoch 80/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3429 - acc: 0.8803 - val_loss: 0.5589 - val_acc: 0.8358
#
# Epoch 00080: val_acc did not improve from 0.86190
#  - lr: 0.00350 - momentum: 0.88
# Epoch 81/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3337 - acc: 0.8844 - val_loss: 0.4708 - val_acc: 0.8541
#
# Epoch 00081: val_acc did not improve from 0.86190
#  - lr: 0.00330 - momentum: 0.89
# Epoch 82/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3402 - acc: 0.8811 - val_loss: 0.4681 - val_acc: 0.8574
#
# Epoch 00082: val_acc did not improve from 0.86190
#  - lr: 0.00310 - momentum: 0.89
# Epoch 83/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3415 - acc: 0.8819 - val_loss: 0.5334 - val_acc: 0.8400
#
# Epoch 00083: val_acc did not improve from 0.86190
#  - lr: 0.00290 - momentum: 0.90
# Epoch 84/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3362 - acc: 0.8819 - val_loss: 0.4439 - val_acc: 0.8570
#
# Epoch 00084: val_acc did not improve from 0.86190
#  - lr: 0.00270 - momentum: 0.90
# Epoch 85/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3260 - acc: 0.8875 - val_loss: 0.4722 - val_acc: 0.8577
#
# Epoch 00085: val_acc did not improve from 0.86190
#  - lr: 0.00250 - momentum: 0.91
# Epoch 86/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3270 - acc: 0.8868 - val_loss: 0.4387 - val_acc: 0.8601
#
# Epoch 00086: val_acc did not improve from 0.86190
#  - lr: 0.00230 - momentum: 0.91
# Epoch 87/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3242 - acc: 0.8868 - val_loss: 0.4906 - val_acc: 0.8559
#
# Epoch 00087: val_acc did not improve from 0.86190
#  - lr: 0.00210 - momentum: 0.91
# Epoch 88/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3216 - acc: 0.8871 - val_loss: 0.4637 - val_acc: 0.8567
#
# Epoch 00088: val_acc did not improve from 0.86190
#  - lr: 0.00190 - momentum: 0.92
# Epoch 89/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3156 - acc: 0.8904 - val_loss: 0.5103 - val_acc: 0.8467
#
# Epoch 00089: val_acc did not improve from 0.86190
#  - lr: 0.00170 - momentum: 0.92
# Epoch 90/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3215 - acc: 0.8877 - val_loss: 0.4503 - val_acc: 0.8551
#
# Epoch 00090: val_acc did not improve from 0.86190
#  - lr: 0.00150 - momentum: 0.93
# Epoch 91/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3156 - acc: 0.8905 - val_loss: 0.4371 - val_acc: 0.8629
#
# Epoch 00091: val_acc improved from 0.86190 to 0.86290, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00130 - momentum: 0.93
# Epoch 92/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3108 - acc: 0.8917 - val_loss: 0.4365 - val_acc: 0.8639
#
# Epoch 00092: val_acc improved from 0.86290 to 0.86390, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00110 - momentum: 0.94
# Epoch 93/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3120 - acc: 0.8915 - val_loss: 0.4309 - val_acc: 0.8628
#
# Epoch 00093: val_acc did not improve from 0.86390
#  - lr: 0.00090 - momentum: 0.94
# Epoch 94/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3063 - acc: 0.8935 - val_loss: 0.4160 - val_acc: 0.8698
#
# Epoch 00094: val_acc improved from 0.86390 to 0.86980, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00070 - momentum: 0.95
# Epoch 95/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3002 - acc: 0.8960 - val_loss: 0.4070 - val_acc: 0.8683
#
# Epoch 00095: val_acc did not improve from 0.86980
#  - lr: 0.00050 - momentum: 0.95
# Epoch 96/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3012 - acc: 0.8947 - val_loss: 0.4069 - val_acc: 0.8711
#
# Epoch 00096: val_acc improved from 0.86980 to 0.87110, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00040 - momentum: 0.95
# Epoch 97/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3007 - acc: 0.8948 - val_loss: 0.4101 - val_acc: 0.8705
#
# Epoch 00097: val_acc did not improve from 0.87110
#  - lr: 0.00030 - momentum: 0.95
# Epoch 98/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3006 - acc: 0.8955 - val_loss: 0.4024 - val_acc: 0.8738
#
# Epoch 00098: val_acc improved from 0.87110 to 0.87380, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00020 - momentum: 0.95
# Epoch 99/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2947 - acc: 0.8988 - val_loss: 0.4009 - val_acc: 0.8749
#
# Epoch 00099: val_acc improved from 0.87380 to 0.87490, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00010 - momentum: 0.95
# Epoch 100/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2918 - acc: 0.8989 - val_loss: 0.3998 - val_acc: 0.8744
#
# Epoch 00100: val_acc did not improve from 0.87490
#  - lr: 0.00001 - momentum: 0.95
# Epoch 101/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2975 - acc: 0.8970 - val_loss: 0.4192 - val_acc: 0.8689
#
# Epoch 00101: val_acc did not improve from 0.87490
#  - lr: 0.00070 - momentum: 0.95
# Epoch 102/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3049 - acc: 0.8953 - val_loss: 0.4249 - val_acc: 0.8687
#
# Epoch 00102: val_acc did not improve from 0.87490
#  - lr: 0.00090 - momentum: 0.94
# Epoch 103/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3037 - acc: 0.8926 - val_loss: 0.4250 - val_acc: 0.8667
#
# Epoch 00103: val_acc did not improve from 0.87490
#  - lr: 0.00110 - momentum: 0.94
# Epoch 104/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3040 - acc: 0.8920 - val_loss: 0.4512 - val_acc: 0.8615
#
# Epoch 00104: val_acc did not improve from 0.87490
#  - lr: 0.00130 - momentum: 0.93
# Epoch 105/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3007 - acc: 0.8966 - val_loss: 0.4295 - val_acc: 0.8656
#
# Epoch 00105: val_acc did not improve from 0.87490
#  - lr: 0.00150 - momentum: 0.93
# Epoch 106/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3044 - acc: 0.8951 - val_loss: 0.4697 - val_acc: 0.8564
#
# Epoch 00106: val_acc did not improve from 0.87490
#  - lr: 0.00170 - momentum: 0.92
# Epoch 107/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3028 - acc: 0.8937 - val_loss: 0.4200 - val_acc: 0.8667
#
# Epoch 00107: val_acc did not improve from 0.87490
#  - lr: 0.00190 - momentum: 0.92
# Epoch 108/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3047 - acc: 0.8942 - val_loss: 0.4139 - val_acc: 0.8694
#
# Epoch 00108: val_acc did not improve from 0.87490
#  - lr: 0.00210 - momentum: 0.91
# Epoch 109/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3033 - acc: 0.8953 - val_loss: 0.4686 - val_acc: 0.8586
#
# Epoch 00109: val_acc did not improve from 0.87490
#  - lr: 0.00230 - momentum: 0.91
# Epoch 110/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2993 - acc: 0.8939 - val_loss: 0.4424 - val_acc: 0.8643
#
# Epoch 00110: val_acc did not improve from 0.87490
#  - lr: 0.00250 - momentum: 0.91
# Epoch 111/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3024 - acc: 0.8953 - val_loss: 0.4390 - val_acc: 0.8653
#
# Epoch 00111: val_acc did not improve from 0.87490
#  - lr: 0.00270 - momentum: 0.90
# Epoch 112/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3004 - acc: 0.8955 - val_loss: 0.4331 - val_acc: 0.8665
#
# Epoch 00112: val_acc did not improve from 0.87490
#  - lr: 0.00290 - momentum: 0.90
# Epoch 113/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3036 - acc: 0.8930 - val_loss: 0.4685 - val_acc: 0.8530
#
# Epoch 00113: val_acc did not improve from 0.87490
#  - lr: 0.00310 - momentum: 0.89
# Epoch 114/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.3095 - acc: 0.8914 - val_loss: 0.5108 - val_acc: 0.8497
#
# Epoch 00114: val_acc did not improve from 0.87490
#  - lr: 0.00330 - momentum: 0.89
# Epoch 115/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2980 - acc: 0.8958 - val_loss: 0.4715 - val_acc: 0.8534
#
# Epoch 00115: val_acc did not improve from 0.87490
#  - lr: 0.00350 - momentum: 0.88
# Epoch 116/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.3001 - acc: 0.8950 - val_loss: 0.5601 - val_acc: 0.8360
#
# Epoch 00116: val_acc did not improve from 0.87490
#  - lr: 0.00370 - momentum: 0.88
# Epoch 117/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2995 - acc: 0.8958 - val_loss: 0.4654 - val_acc: 0.8558
#
# Epoch 00117: val_acc did not improve from 0.87490
#  - lr: 0.00390 - momentum: 0.87
# Epoch 118/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2951 - acc: 0.8984 - val_loss: 0.4291 - val_acc: 0.8713
#
# Epoch 00118: val_acc did not improve from 0.87490
#  - lr: 0.00410 - momentum: 0.87
# Epoch 119/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2930 - acc: 0.8968 - val_loss: 0.4505 - val_acc: 0.8613
#
# Epoch 00119: val_acc did not improve from 0.87490
#  - lr: 0.00430 - momentum: 0.87
# Epoch 120/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2941 - acc: 0.8975 - val_loss: 0.4831 - val_acc: 0.8536
#
# Epoch 00120: val_acc did not improve from 0.87490
#  - lr: 0.00450 - momentum: 0.86
# Epoch 121/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2920 - acc: 0.8969 - val_loss: 0.4910 - val_acc: 0.8524
#
# Epoch 00121: val_acc did not improve from 0.87490
#  - lr: 0.00470 - momentum: 0.86
# Epoch 122/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2937 - acc: 0.8979 - val_loss: 0.4889 - val_acc: 0.8551
#
# Epoch 00122: val_acc did not improve from 0.87490
#  - lr: 0.00490 - momentum: 0.85
# Epoch 123/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2873 - acc: 0.8992 - val_loss: 0.4694 - val_acc: 0.8614
#
# Epoch 00123: val_acc did not improve from 0.87490
#  - lr: 0.00490 - momentum: 0.85
# Epoch 124/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2966 - acc: 0.8958 - val_loss: 0.4367 - val_acc: 0.8618
#
# Epoch 00124: val_acc did not improve from 0.87490
#  - lr: 0.00470 - momentum: 0.86
# Epoch 125/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2873 - acc: 0.8995 - val_loss: 0.4902 - val_acc: 0.8552
#
# Epoch 00125: val_acc did not improve from 0.87490
#  - lr: 0.00450 - momentum: 0.86
# Epoch 126/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2858 - acc: 0.9008 - val_loss: 0.4569 - val_acc: 0.8586
#
# Epoch 00126: val_acc did not improve from 0.87490
#  - lr: 0.00430 - momentum: 0.87
# Epoch 127/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2817 - acc: 0.9020 - val_loss: 0.4423 - val_acc: 0.8695
#
# Epoch 00127: val_acc did not improve from 0.87490
#  - lr: 0.00410 - momentum: 0.87
# Epoch 128/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2789 - acc: 0.9022 - val_loss: 0.4656 - val_acc: 0.8643
#
# Epoch 00128: val_acc did not improve from 0.87490
#  - lr: 0.00390 - momentum: 0.87
# Epoch 129/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2822 - acc: 0.9016 - val_loss: 0.4819 - val_acc: 0.8610
#
# Epoch 00129: val_acc did not improve from 0.87490
#  - lr: 0.00370 - momentum: 0.88
# Epoch 130/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2829 - acc: 0.9018 - val_loss: 0.4584 - val_acc: 0.8586
#
# Epoch 00130: val_acc did not improve from 0.87490
#  - lr: 0.00350 - momentum: 0.88
# Epoch 131/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2766 - acc: 0.9035 - val_loss: 0.4546 - val_acc: 0.8660
#
# Epoch 00131: val_acc did not improve from 0.87490
#  - lr: 0.00330 - momentum: 0.89
# Epoch 132/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2781 - acc: 0.9022 - val_loss: 0.4749 - val_acc: 0.8605
#
# Epoch 00132: val_acc did not improve from 0.87490
#  - lr: 0.00310 - momentum: 0.89
# Epoch 133/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2768 - acc: 0.9025 - val_loss: 0.4292 - val_acc: 0.8664
#
# Epoch 00133: val_acc did not improve from 0.87490
#  - lr: 0.00290 - momentum: 0.90
# Epoch 134/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2765 - acc: 0.9021 - val_loss: 0.4829 - val_acc: 0.8609
#
# Epoch 00134: val_acc did not improve from 0.87490
#  - lr: 0.00270 - momentum: 0.90
# Epoch 135/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2712 - acc: 0.9055 - val_loss: 0.4245 - val_acc: 0.8701
#
# Epoch 00135: val_acc did not improve from 0.87490
#  - lr: 0.00250 - momentum: 0.91
# Epoch 136/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2728 - acc: 0.9054 - val_loss: 0.4731 - val_acc: 0.8583
#
# Epoch 00136: val_acc did not improve from 0.87490
#  - lr: 0.00230 - momentum: 0.91
# Epoch 137/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2703 - acc: 0.9053 - val_loss: 0.4567 - val_acc: 0.8658
#
# Epoch 00137: val_acc did not improve from 0.87490
#  - lr: 0.00210 - momentum: 0.91
# Epoch 138/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2720 - acc: 0.9056 - val_loss: 0.4361 - val_acc: 0.8670
#
# Epoch 00138: val_acc did not improve from 0.87490
#  - lr: 0.00190 - momentum: 0.92
# Epoch 139/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2686 - acc: 0.9055 - val_loss: 0.4247 - val_acc: 0.8700
#
# Epoch 00139: val_acc did not improve from 0.87490
#  - lr: 0.00170 - momentum: 0.92
# Epoch 140/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2682 - acc: 0.9047 - val_loss: 0.4196 - val_acc: 0.8707
#
# Epoch 00140: val_acc did not improve from 0.87490
#  - lr: 0.00150 - momentum: 0.93
# Epoch 141/300
# 390/390 [==============================] - 85s 218ms/step - loss: 0.2629 - acc: 0.9085 - val_loss: 0.4195 - val_acc: 0.8734
#
# Epoch 00141: val_acc did not improve from 0.87490
#  - lr: 0.00130 - momentum: 0.93
# Epoch 142/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2616 - acc: 0.9085 - val_loss: 0.4261 - val_acc: 0.8687
#
# Epoch 00142: val_acc did not improve from 0.87490
#  - lr: 0.00110 - momentum: 0.94
# Epoch 143/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2633 - acc: 0.9074 - val_loss: 0.4161 - val_acc: 0.8757
#
# Epoch 00143: val_acc improved from 0.87490 to 0.87570, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00090 - momentum: 0.94
# Epoch 144/300
# 390/390 [==============================] - 84s 217ms/step - loss: 0.2568 - acc: 0.9102 - val_loss: 0.4082 - val_acc: 0.8724
#
# Epoch 00144: val_acc did not improve from 0.87570
#  - lr: 0.00070 - momentum: 0.95
# Epoch 145/300
# 390/390 [==============================] - 84s 217ms/step - loss: 0.2550 - acc: 0.9104 - val_loss: 0.4145 - val_acc: 0.8761
#
# Epoch 00145: val_acc improved from 0.87570 to 0.87610, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00050 - momentum: 0.95
# Epoch 146/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2563 - acc: 0.9095 - val_loss: 0.4124 - val_acc: 0.8769
#
# Epoch 00146: val_acc improved from 0.87610 to 0.87690, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00040 - momentum: 0.95
# Epoch 147/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2517 - acc: 0.9115 - val_loss: 0.4199 - val_acc: 0.8738
#
# Epoch 00147: val_acc did not improve from 0.87690
#  - lr: 0.00030 - momentum: 0.95
# Epoch 148/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2512 - acc: 0.9117 - val_loss: 0.4075 - val_acc: 0.8777
#
# Epoch 00148: val_acc improved from 0.87690 to 0.87770, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00020 - momentum: 0.95
# Epoch 149/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2527 - acc: 0.9111 - val_loss: 0.4087 - val_acc: 0.8772
#
# Epoch 00149: val_acc did not improve from 0.87770
#  - lr: 0.00010 - momentum: 0.95
# Epoch 150/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2526 - acc: 0.9125 - val_loss: 0.4076 - val_acc: 0.8782
#
# Epoch 00150: val_acc improved from 0.87770 to 0.87820, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00001 - momentum: 0.95
# Epoch 151/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2525 - acc: 0.9120 - val_loss: 0.4292 - val_acc: 0.8729
#
# Epoch 00151: val_acc did not improve from 0.87820
#  - lr: 0.00070 - momentum: 0.95
# Epoch 152/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2606 - acc: 0.9091 - val_loss: 0.4259 - val_acc: 0.8714
#
# Epoch 00152: val_acc did not improve from 0.87820
#  - lr: 0.00090 - momentum: 0.94
# Epoch 153/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2538 - acc: 0.9129 - val_loss: 0.4245 - val_acc: 0.8714
#
# Epoch 00153: val_acc did not improve from 0.87820
#  - lr: 0.00110 - momentum: 0.94
# Epoch 154/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2584 - acc: 0.9094 - val_loss: 0.4404 - val_acc: 0.8706
#
# Epoch 00154: val_acc did not improve from 0.87820
#  - lr: 0.00130 - momentum: 0.93
# Epoch 155/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2556 - acc: 0.9111 - val_loss: 0.4346 - val_acc: 0.8705
#
# Epoch 00155: val_acc did not improve from 0.87820
#  - lr: 0.00150 - momentum: 0.93
# Epoch 156/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2577 - acc: 0.9086 - val_loss: 0.4370 - val_acc: 0.8713
#
# Epoch 00156: val_acc did not improve from 0.87820
#  - lr: 0.00170 - momentum: 0.92
# Epoch 157/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2595 - acc: 0.9091 - val_loss: 0.4423 - val_acc: 0.8684
#
# Epoch 00157: val_acc did not improve from 0.87820
#  - lr: 0.00190 - momentum: 0.92
# Epoch 158/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2529 - acc: 0.9114 - val_loss: 0.4478 - val_acc: 0.8692
#
# Epoch 00158: val_acc did not improve from 0.87820
#  - lr: 0.00210 - momentum: 0.91
# Epoch 159/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2579 - acc: 0.9091 - val_loss: 0.4625 - val_acc: 0.8627
#
# Epoch 00159: val_acc did not improve from 0.87820
#  - lr: 0.00230 - momentum: 0.91
# Epoch 160/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2599 - acc: 0.9087 - val_loss: 0.5021 - val_acc: 0.8526
#
# Epoch 00160: val_acc did not improve from 0.87820
#  - lr: 0.00250 - momentum: 0.91
# Epoch 161/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2550 - acc: 0.9108 - val_loss: 0.4651 - val_acc: 0.8670
#
# Epoch 00161: val_acc did not improve from 0.87820
#  - lr: 0.00270 - momentum: 0.90
# Epoch 162/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2559 - acc: 0.9106 - val_loss: 0.4900 - val_acc: 0.8598
#
# Epoch 00162: val_acc did not improve from 0.87820
#  - lr: 0.00290 - momentum: 0.90
# Epoch 163/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2571 - acc: 0.9101 - val_loss: 0.4473 - val_acc: 0.8655
#
# Epoch 00163: val_acc did not improve from 0.87820
#  - lr: 0.00310 - momentum: 0.89
# Epoch 164/300
# 390/390 [==============================] - 84s 217ms/step - loss: 0.2537 - acc: 0.9110 - val_loss: 0.4447 - val_acc: 0.8683
#
# Epoch 00164: val_acc did not improve from 0.87820
#  - lr: 0.00330 - momentum: 0.89
# Epoch 165/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2574 - acc: 0.9109 - val_loss: 0.4556 - val_acc: 0.8655
#
# Epoch 00165: val_acc did not improve from 0.87820
#  - lr: 0.00350 - momentum: 0.88
# Epoch 166/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2495 - acc: 0.9119 - val_loss: 0.4615 - val_acc: 0.8644
#
# Epoch 00166: val_acc did not improve from 0.87820
#  - lr: 0.00370 - momentum: 0.88
# Epoch 167/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2568 - acc: 0.9088 - val_loss: 0.4558 - val_acc: 0.8651
#
# Epoch 00167: val_acc did not improve from 0.87820
#  - lr: 0.00390 - momentum: 0.87
# Epoch 168/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2502 - acc: 0.9120 - val_loss: 0.4719 - val_acc: 0.8621
#
# Epoch 00168: val_acc did not improve from 0.87820
#  - lr: 0.00410 - momentum: 0.87
# Epoch 169/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2522 - acc: 0.9111 - val_loss: 0.4740 - val_acc: 0.8617
#
# Epoch 00169: val_acc did not improve from 0.87820
#  - lr: 0.00430 - momentum: 0.87
# Epoch 170/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2496 - acc: 0.9121 - val_loss: 0.4670 - val_acc: 0.8657
#
# Epoch 00170: val_acc did not improve from 0.87820
#  - lr: 0.00450 - momentum: 0.86
# Epoch 171/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2553 - acc: 0.9101 - val_loss: 0.4450 - val_acc: 0.8691
#
# Epoch 00171: val_acc did not improve from 0.87820
#  - lr: 0.00470 - momentum: 0.86
# Epoch 172/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2484 - acc: 0.9129 - val_loss: 0.4797 - val_acc: 0.8628
#
# Epoch 00172: val_acc did not improve from 0.87820
#  - lr: 0.00490 - momentum: 0.85
# Epoch 173/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2559 - acc: 0.9104 - val_loss: 0.4628 - val_acc: 0.8654
#
# Epoch 00173: val_acc did not improve from 0.87820
#  - lr: 0.00490 - momentum: 0.85
# Epoch 174/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2423 - acc: 0.9148 - val_loss: 0.4323 - val_acc: 0.8706
#
# Epoch 00174: val_acc did not improve from 0.87820
#  - lr: 0.00470 - momentum: 0.86
# Epoch 175/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2492 - acc: 0.9141 - val_loss: 0.4328 - val_acc: 0.8723
#
# Epoch 00175: val_acc did not improve from 0.87820
#  - lr: 0.00450 - momentum: 0.86
# Epoch 176/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2481 - acc: 0.9129 - val_loss: 0.4508 - val_acc: 0.8699
#
# Epoch 00176: val_acc did not improve from 0.87820
#  - lr: 0.00430 - momentum: 0.87
# Epoch 177/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2471 - acc: 0.9134 - val_loss: 0.4541 - val_acc: 0.8658
#
# Epoch 00177: val_acc did not improve from 0.87820
#  - lr: 0.00410 - momentum: 0.87
# Epoch 178/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2487 - acc: 0.9121 - val_loss: 0.4887 - val_acc: 0.8605
#
# Epoch 00178: val_acc did not improve from 0.87820
#  - lr: 0.00390 - momentum: 0.87
# Epoch 179/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2460 - acc: 0.9147 - val_loss: 0.4621 - val_acc: 0.8674
#
# Epoch 00179: val_acc did not improve from 0.87820
#  - lr: 0.00370 - momentum: 0.88
# Epoch 180/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2478 - acc: 0.9113 - val_loss: 0.5073 - val_acc: 0.8594
#
# Epoch 00180: val_acc did not improve from 0.87820
#  - lr: 0.00350 - momentum: 0.88
# Epoch 181/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2427 - acc: 0.9147 - val_loss: 0.4566 - val_acc: 0.8666
#
# Epoch 00181: val_acc did not improve from 0.87820
#  - lr: 0.00330 - momentum: 0.89
# Epoch 182/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2410 - acc: 0.9152 - val_loss: 0.5025 - val_acc: 0.8599
#
# Epoch 00182: val_acc did not improve from 0.87820
#  - lr: 0.00310 - momentum: 0.89
# Epoch 183/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2388 - acc: 0.9167 - val_loss: 0.4366 - val_acc: 0.8751
#
# Epoch 00183: val_acc did not improve from 0.87820
#  - lr: 0.00290 - momentum: 0.90
# Epoch 184/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2443 - acc: 0.9152 - val_loss: 0.4713 - val_acc: 0.8690
#
# Epoch 00184: val_acc did not improve from 0.87820
#  - lr: 0.00270 - momentum: 0.90
# Epoch 185/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2404 - acc: 0.9155 - val_loss: 0.4370 - val_acc: 0.8703
#
# Epoch 00185: val_acc did not improve from 0.87820
#  - lr: 0.00250 - momentum: 0.91
# Epoch 186/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2385 - acc: 0.9181 - val_loss: 0.4694 - val_acc: 0.8677
#
# Epoch 00186: val_acc did not improve from 0.87820
#  - lr: 0.00230 - momentum: 0.91
# Epoch 187/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2338 - acc: 0.9176 - val_loss: 0.4518 - val_acc: 0.8725
#
# Epoch 00187: val_acc did not improve from 0.87820
#  - lr: 0.00210 - momentum: 0.91
# Epoch 188/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2379 - acc: 0.9179 - val_loss: 0.4373 - val_acc: 0.8725
#
# Epoch 00188: val_acc did not improve from 0.87820
#  - lr: 0.00190 - momentum: 0.92
# Epoch 189/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2341 - acc: 0.9188 - val_loss: 0.4454 - val_acc: 0.8660
#
# Epoch 00189: val_acc did not improve from 0.87820
#  - lr: 0.00170 - momentum: 0.92
# Epoch 190/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2314 - acc: 0.9187 - val_loss: 0.4313 - val_acc: 0.8728
#
# Epoch 00190: val_acc did not improve from 0.87820
#  - lr: 0.00150 - momentum: 0.93
# Epoch 191/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2332 - acc: 0.9178 - val_loss: 0.4359 - val_acc: 0.8712
#
# Epoch 00191: val_acc did not improve from 0.87820
#  - lr: 0.00130 - momentum: 0.93
# Epoch 192/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2309 - acc: 0.9198 - val_loss: 0.4204 - val_acc: 0.8774
#
# Epoch 00192: val_acc did not improve from 0.87820
#  - lr: 0.00110 - momentum: 0.94
# Epoch 193/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2318 - acc: 0.9199 - val_loss: 0.4218 - val_acc: 0.8756
#
# Epoch 00193: val_acc did not improve from 0.87820
#  - lr: 0.00090 - momentum: 0.94
# Epoch 194/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2317 - acc: 0.9197 - val_loss: 0.4300 - val_acc: 0.8742
#
# Epoch 00194: val_acc did not improve from 0.87820
#  - lr: 0.00070 - momentum: 0.95
# Epoch 195/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2283 - acc: 0.9212 - val_loss: 0.4338 - val_acc: 0.8760
#
# Epoch 00195: val_acc did not improve from 0.87820
#  - lr: 0.00050 - momentum: 0.95
# Epoch 196/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2256 - acc: 0.9216 - val_loss: 0.4202 - val_acc: 0.8782
#
# Epoch 00196: val_acc did not improve from 0.87820
#  - lr: 0.00040 - momentum: 0.95
# Epoch 197/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2257 - acc: 0.9203 - val_loss: 0.4127 - val_acc: 0.8776
#
# Epoch 00197: val_acc did not improve from 0.87820
#  - lr: 0.00030 - momentum: 0.95
# Epoch 198/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2222 - acc: 0.9234 - val_loss: 0.4182 - val_acc: 0.8788
#
# Epoch 00198: val_acc improved from 0.87820 to 0.87880, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00020 - momentum: 0.95
# Epoch 199/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2223 - acc: 0.9242 - val_loss: 0.4165 - val_acc: 0.8789
#
# Epoch 00199: val_acc improved from 0.87880 to 0.87890, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00010 - momentum: 0.95
# Epoch 200/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2262 - acc: 0.9208 - val_loss: 0.4138 - val_acc: 0.8795
#
# Epoch 00200: val_acc improved from 0.87890 to 0.87950, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00001 - momentum: 0.95
# Epoch 201/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2249 - acc: 0.9216 - val_loss: 0.4354 - val_acc: 0.8745
#
# Epoch 00201: val_acc did not improve from 0.87950
#  - lr: 0.00070 - momentum: 0.95
# Epoch 202/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2258 - acc: 0.9223 - val_loss: 0.4349 - val_acc: 0.8742
#
# Epoch 00202: val_acc did not improve from 0.87950
#  - lr: 0.00090 - momentum: 0.94
# Epoch 203/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2274 - acc: 0.9220 - val_loss: 0.4311 - val_acc: 0.8774
#
# Epoch 00203: val_acc did not improve from 0.87950
#  - lr: 0.00110 - momentum: 0.94
# Epoch 204/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2284 - acc: 0.9203 - val_loss: 0.4330 - val_acc: 0.8730
#
# Epoch 00204: val_acc did not improve from 0.87950
#  - lr: 0.00130 - momentum: 0.93
# Epoch 205/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2335 - acc: 0.9194 - val_loss: 0.4591 - val_acc: 0.8703
#
# Epoch 00205: val_acc did not improve from 0.87950
#  - lr: 0.00150 - momentum: 0.93
# Epoch 206/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2283 - acc: 0.9214 - val_loss: 0.4533 - val_acc: 0.8709
#
# Epoch 00206: val_acc did not improve from 0.87950
#  - lr: 0.00170 - momentum: 0.92
# Epoch 207/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2331 - acc: 0.9172 - val_loss: 0.4482 - val_acc: 0.8722
#
# Epoch 00207: val_acc did not improve from 0.87950
#  - lr: 0.00190 - momentum: 0.92
# Epoch 208/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2331 - acc: 0.9186 - val_loss: 0.4372 - val_acc: 0.8749
#
# Epoch 00208: val_acc did not improve from 0.87950
#  - lr: 0.00210 - momentum: 0.91
# Epoch 209/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2316 - acc: 0.9191 - val_loss: 0.4646 - val_acc: 0.8707
#
# Epoch 00209: val_acc did not improve from 0.87950
#  - lr: 0.00230 - momentum: 0.91
# Epoch 210/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2288 - acc: 0.9202 - val_loss: 0.4634 - val_acc: 0.8687
#
# Epoch 00210: val_acc did not improve from 0.87950
#  - lr: 0.00250 - momentum: 0.91
# Epoch 211/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2303 - acc: 0.9192 - val_loss: 0.4709 - val_acc: 0.8697
#
# Epoch 00211: val_acc did not improve from 0.87950
#  - lr: 0.00270 - momentum: 0.90
# Epoch 212/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2288 - acc: 0.9192 - val_loss: 0.4557 - val_acc: 0.8699
#
# Epoch 00212: val_acc did not improve from 0.87950
#  - lr: 0.00290 - momentum: 0.90
# Epoch 213/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2260 - acc: 0.9224 - val_loss: 0.4770 - val_acc: 0.8697
#
# Epoch 00213: val_acc did not improve from 0.87950
#  - lr: 0.00310 - momentum: 0.89
# Epoch 214/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2256 - acc: 0.9205 - val_loss: 0.4529 - val_acc: 0.8698
#
# Epoch 00214: val_acc did not improve from 0.87950
#  - lr: 0.00330 - momentum: 0.89
# Epoch 215/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2246 - acc: 0.9204 - val_loss: 0.4342 - val_acc: 0.8749
#
# Epoch 00215: val_acc did not improve from 0.87950
#  - lr: 0.00350 - momentum: 0.88
# Epoch 216/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2306 - acc: 0.9173 - val_loss: 0.5179 - val_acc: 0.8593
#
# Epoch 00216: val_acc did not improve from 0.87950
#  - lr: 0.00370 - momentum: 0.88
# Epoch 217/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2247 - acc: 0.9220 - val_loss: 0.4495 - val_acc: 0.8728
#
# Epoch 00217: val_acc did not improve from 0.87950
#  - lr: 0.00390 - momentum: 0.87
# Epoch 218/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2282 - acc: 0.9220 - val_loss: 0.4546 - val_acc: 0.8741
#
# Epoch 00218: val_acc did not improve from 0.87950
#  - lr: 0.00410 - momentum: 0.87
# Epoch 219/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2268 - acc: 0.9195 - val_loss: 0.4526 - val_acc: 0.8732
#
# Epoch 00219: val_acc did not improve from 0.87950
#  - lr: 0.00430 - momentum: 0.87
# Epoch 220/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2277 - acc: 0.9202 - val_loss: 0.4717 - val_acc: 0.8706
#
# Epoch 00220: val_acc did not improve from 0.87950
#  - lr: 0.00450 - momentum: 0.86
# Epoch 221/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2267 - acc: 0.9212 - val_loss: 0.4412 - val_acc: 0.8707
#
# Epoch 00221: val_acc did not improve from 0.87950
#  - lr: 0.00470 - momentum: 0.86
# Epoch 222/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2260 - acc: 0.9199 - val_loss: 0.4878 - val_acc: 0.8648
#
# Epoch 00222: val_acc did not improve from 0.87950
#  - lr: 0.00490 - momentum: 0.85
# Epoch 223/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2289 - acc: 0.9190 - val_loss: 0.4885 - val_acc: 0.8640
#
# Epoch 00223: val_acc did not improve from 0.87950
#  - lr: 0.00490 - momentum: 0.85
# Epoch 224/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2239 - acc: 0.9208 - val_loss: 0.4311 - val_acc: 0.8726
#
# Epoch 00224: val_acc did not improve from 0.87950
#  - lr: 0.00470 - momentum: 0.86
# Epoch 225/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2220 - acc: 0.9220 - val_loss: 0.4305 - val_acc: 0.8744
#
# Epoch 00225: val_acc did not improve from 0.87950
#  - lr: 0.00450 - momentum: 0.86
# Epoch 226/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2259 - acc: 0.9209 - val_loss: 0.4373 - val_acc: 0.8752
#
# Epoch 00226: val_acc did not improve from 0.87950
#  - lr: 0.00430 - momentum: 0.87
# Epoch 227/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2220 - acc: 0.9215 - val_loss: 0.5013 - val_acc: 0.8633
#
# Epoch 00227: val_acc did not improve from 0.87950
#  - lr: 0.00410 - momentum: 0.87
# Epoch 228/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2225 - acc: 0.9220 - val_loss: 0.4640 - val_acc: 0.8688
#
# Epoch 00228: val_acc did not improve from 0.87950
#  - lr: 0.00390 - momentum: 0.87
# Epoch 229/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2241 - acc: 0.9207 - val_loss: 0.4414 - val_acc: 0.8749
#
# Epoch 00229: val_acc did not improve from 0.87950
#  - lr: 0.00370 - momentum: 0.88
# Epoch 230/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2194 - acc: 0.9224 - val_loss: 0.4746 - val_acc: 0.8644
#
# Epoch 00230: val_acc did not improve from 0.87950
#  - lr: 0.00350 - momentum: 0.88
# Epoch 231/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2239 - acc: 0.9208 - val_loss: 0.4609 - val_acc: 0.8729
#
# Epoch 00231: val_acc did not improve from 0.87950
#  - lr: 0.00330 - momentum: 0.89
# Epoch 232/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2151 - acc: 0.9242 - val_loss: 0.4684 - val_acc: 0.8674
#
# Epoch 00232: val_acc did not improve from 0.87950
#  - lr: 0.00310 - momentum: 0.89
# Epoch 233/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2127 - acc: 0.9244 - val_loss: 0.4360 - val_acc: 0.8771
#
# Epoch 00233: val_acc did not improve from 0.87950
#  - lr: 0.00290 - momentum: 0.90
# Epoch 234/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2178 - acc: 0.9234 - val_loss: 0.4569 - val_acc: 0.8730
#
# Epoch 00234: val_acc did not improve from 0.87950
#  - lr: 0.00270 - momentum: 0.90
# Epoch 235/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2149 - acc: 0.9254 - val_loss: 0.4404 - val_acc: 0.8761
#
# Epoch 00235: val_acc did not improve from 0.87950
#  - lr: 0.00250 - momentum: 0.91
# Epoch 236/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2194 - acc: 0.9236 - val_loss: 0.4646 - val_acc: 0.8705
#
# Epoch 00236: val_acc did not improve from 0.87950
#  - lr: 0.00230 - momentum: 0.91
# Epoch 237/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2151 - acc: 0.9261 - val_loss: 0.4472 - val_acc: 0.8759
#
# Epoch 00237: val_acc did not improve from 0.87950
#  - lr: 0.00210 - momentum: 0.91
# Epoch 238/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2134 - acc: 0.9261 - val_loss: 0.4773 - val_acc: 0.8701
#
# Epoch 00238: val_acc did not improve from 0.87950
#  - lr: 0.00190 - momentum: 0.92
# Epoch 239/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2083 - acc: 0.9272 - val_loss: 0.4355 - val_acc: 0.8757
#
# Epoch 00239: val_acc did not improve from 0.87950
#  - lr: 0.00170 - momentum: 0.92
# Epoch 240/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2205 - acc: 0.9230 - val_loss: 0.4315 - val_acc: 0.8756
#
# Epoch 00240: val_acc did not improve from 0.87950
#  - lr: 0.00150 - momentum: 0.93
# Epoch 241/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2144 - acc: 0.9256 - val_loss: 0.4321 - val_acc: 0.8783
#
# Epoch 00241: val_acc did not improve from 0.87950
#  - lr: 0.00130 - momentum: 0.93
# Epoch 242/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2088 - acc: 0.9273 - val_loss: 0.4313 - val_acc: 0.8785
#
# Epoch 00242: val_acc did not improve from 0.87950
#  - lr: 0.00110 - momentum: 0.94
# Epoch 243/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2063 - acc: 0.9278 - val_loss: 0.4374 - val_acc: 0.8771
#
# Epoch 00243: val_acc did not improve from 0.87950
#  - lr: 0.00090 - momentum: 0.94
# Epoch 244/300
# 390/390 [==============================] - 84s 216ms/step - loss: 0.2095 - acc: 0.9266 - val_loss: 0.4379 - val_acc: 0.8779
#
# Epoch 00244: val_acc did not improve from 0.87950
#  - lr: 0.00070 - momentum: 0.95
# Epoch 245/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2111 - acc: 0.9260 - val_loss: 0.4192 - val_acc: 0.8787
#
# Epoch 00245: val_acc did not improve from 0.87950
#  - lr: 0.00050 - momentum: 0.95
# Epoch 246/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2051 - acc: 0.9295 - val_loss: 0.4277 - val_acc: 0.8789
#
# Epoch 00246: val_acc did not improve from 0.87950
#  - lr: 0.00040 - momentum: 0.95
# Epoch 247/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2067 - acc: 0.9290 - val_loss: 0.4247 - val_acc: 0.8817
#
# Epoch 00247: val_acc improved from 0.87950 to 0.88170, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00030 - momentum: 0.95
# Epoch 248/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2055 - acc: 0.9288 - val_loss: 0.4198 - val_acc: 0.8803
#
# Epoch 00248: val_acc did not improve from 0.88170
#  - lr: 0.00020 - momentum: 0.95
# Epoch 249/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2068 - acc: 0.9289 - val_loss: 0.4216 - val_acc: 0.8820
#
# Epoch 00249: val_acc improved from 0.88170 to 0.88200, saving model to /content/gdrive/My Drive/Resnet-13.hdf5
#  - lr: 0.00010 - momentum: 0.95
# Epoch 250/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2080 - acc: 0.9266 - val_loss: 0.4203 - val_acc: 0.8819
#
# Epoch 00250: val_acc did not improve from 0.88200
#  - lr: 0.00001 - momentum: 0.95
# Epoch 251/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2079 - acc: 0.9285 - val_loss: 0.4513 - val_acc: 0.8740
#
# Epoch 00251: val_acc did not improve from 0.88200
#  - lr: 0.00070 - momentum: 0.95
# Epoch 252/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2029 - acc: 0.9284 - val_loss: 0.4306 - val_acc: 0.8787
#
# Epoch 00252: val_acc did not improve from 0.88200
#  - lr: 0.00090 - momentum: 0.94
# Epoch 253/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2048 - acc: 0.9307 - val_loss: 0.4449 - val_acc: 0.8746
#
# Epoch 00253: val_acc did not improve from 0.88200
#  - lr: 0.00110 - momentum: 0.94
# Epoch 254/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2046 - acc: 0.9281 - val_loss: 0.4391 - val_acc: 0.8763
#
# Epoch 00254: val_acc did not improve from 0.88200
#  - lr: 0.00130 - momentum: 0.93
# Epoch 255/300
# 390/390 [==============================] - 85s 217ms/step - loss: 0.2083 - acc: 0.9281 - val_loss: 0.4288 - val_acc: 0.8786
#
# Epoch 00255: val_acc did not improve from 0.88200
#  - lr: 0.00150 - momentum: 0.93
# Epoch 256/300
# 224/390 [================>.............] - ETA: 33s - loss: 0.2141 - acc: 0.9268
