# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(48, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(Convolution2D(48, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(96, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(96, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(192, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(192, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3))`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3))`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3))`
#   app.launch_new_instance()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_31 (Conv2D)           (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_27 (Activation)   (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 30, 30, 48)        20784
# _________________________________________________________________
# activation_28 (Activation)   (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 15, 15, 48)        0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 15, 15, 96)        41568
# _________________________________________________________________
# activation_29 (Activation)   (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 13, 13, 96)        83040
# _________________________________________________________________
# activation_30 (Activation)   (None, 13, 13, 96)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 6, 6, 96)          0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 6, 6, 96)          0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 6, 6, 192)         166080
# _________________________________________________________________
# activation_31 (Activation)   (None, 6, 6, 192)         0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 4, 4, 192)         331968
# _________________________________________________________________
# activation_32 (Activation)   (None, 4, 4, 192)         0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 2, 2, 192)         0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 2, 2, 192)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 768)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               393728
# _________________________________________________________________
# activation_33 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_34 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,172,410
# Trainable params: 1,172,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=50)`
#   if sys.path[0] == '':
# Epoch 1/50
# 390/390 [==============================] - 10s 27ms/step - loss: 1.9196 - acc: 0.2540 - val_loss: 1.5198 - val_acc: 0.4360
# Epoch 2/50
# 390/390 [==============================] - 9s 23ms/step - loss: 1.4079 - acc: 0.4879 - val_loss: 1.1444 - val_acc: 0.5866
# Epoch 3/50
# 390/390 [==============================] - 9s 23ms/step - loss: 1.1603 - acc: 0.5888 - val_loss: 0.9892 - val_acc: 0.6525
# Epoch 4/50
# 390/390 [==============================] - 9s 23ms/step - loss: 1.0165 - acc: 0.6460 - val_loss: 0.9154 - val_acc: 0.6775
# Epoch 5/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.9063 - acc: 0.6889 - val_loss: 0.8142 - val_acc: 0.7200
# Epoch 6/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.8179 - acc: 0.7186 - val_loss: 0.7298 - val_acc: 0.7501
# Epoch 7/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.7743 - acc: 0.7367 - val_loss: 0.6891 - val_acc: 0.7662
# Epoch 8/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.7176 - acc: 0.7542 - val_loss: 0.6974 - val_acc: 0.7641
# Epoch 9/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6938 - acc: 0.7639 - val_loss: 0.6596 - val_acc: 0.7729
# Epoch 10/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6615 - acc: 0.7748 - val_loss: 0.6566 - val_acc: 0.7768
# Epoch 11/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6334 - acc: 0.7823 - val_loss: 0.6594 - val_acc: 0.7798
# Epoch 12/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6024 - acc: 0.7938 - val_loss: 0.6783 - val_acc: 0.7776
# Epoch 13/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5946 - acc: 0.7969 - val_loss: 0.6268 - val_acc: 0.7914
# Epoch 14/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5732 - acc: 0.8054 - val_loss: 0.6008 - val_acc: 0.8014
# Epoch 15/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5539 - acc: 0.8092 - val_loss: 0.5956 - val_acc: 0.7955
# Epoch 16/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5449 - acc: 0.8153 - val_loss: 0.6013 - val_acc: 0.8014
# Epoch 17/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5275 - acc: 0.8206 - val_loss: 0.6313 - val_acc: 0.7951
# Epoch 18/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5172 - acc: 0.8238 - val_loss: 0.5652 - val_acc: 0.8130
# Epoch 19/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5040 - acc: 0.8277 - val_loss: 0.5839 - val_acc: 0.8090
# Epoch 20/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4957 - acc: 0.8310 - val_loss: 0.5924 - val_acc: 0.8069
# Epoch 21/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4848 - acc: 0.8333 - val_loss: 0.5808 - val_acc: 0.8121
# Epoch 22/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4668 - acc: 0.8399 - val_loss: 0.5888 - val_acc: 0.8045
# Epoch 23/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4724 - acc: 0.8394 - val_loss: 0.5894 - val_acc: 0.8065
# Epoch 24/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4636 - acc: 0.8417 - val_loss: 0.5701 - val_acc: 0.8120
# Epoch 25/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4645 - acc: 0.8420 - val_loss: 0.5671 - val_acc: 0.8118
# Epoch 26/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4459 - acc: 0.8477 - val_loss: 0.5852 - val_acc: 0.8143
# Epoch 27/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4362 - acc: 0.8509 - val_loss: 0.5565 - val_acc: 0.8156
# Epoch 28/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4406 - acc: 0.8500 - val_loss: 0.5645 - val_acc: 0.8178
# Epoch 29/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4274 - acc: 0.8542 - val_loss: 0.5664 - val_acc: 0.8170
# Epoch 30/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4161 - acc: 0.8568 - val_loss: 0.5752 - val_acc: 0.8204
# Epoch 31/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4167 - acc: 0.8575 - val_loss: 0.5641 - val_acc: 0.8138
# Epoch 32/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4198 - acc: 0.8579 - val_loss: 0.5974 - val_acc: 0.8110
# Epoch 33/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4124 - acc: 0.8602 - val_loss: 0.5869 - val_acc: 0.8146
# Epoch 34/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4122 - acc: 0.8612 - val_loss: 0.5616 - val_acc: 0.8225
# Epoch 35/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3974 - acc: 0.8643 - val_loss: 0.5706 - val_acc: 0.8183
# Epoch 36/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3955 - acc: 0.8659 - val_loss: 0.5723 - val_acc: 0.8210
# Epoch 37/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3967 - acc: 0.8658 - val_loss: 0.6008 - val_acc: 0.8102
# Epoch 38/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3918 - acc: 0.8665 - val_loss: 0.5714 - val_acc: 0.8206
# Epoch 39/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3846 - acc: 0.8700 - val_loss: 0.5698 - val_acc: 0.8258
# Epoch 40/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3823 - acc: 0.8698 - val_loss: 0.5542 - val_acc: 0.8259
# Epoch 41/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3723 - acc: 0.8747 - val_loss: 0.5720 - val_acc: 0.8215
# Epoch 42/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3721 - acc: 0.8741 - val_loss: 0.5711 - val_acc: 0.8218
# Epoch 43/50
# 390/390 [==============================] - 9s 24ms/step - loss: 0.3726 - acc: 0.8746 - val_loss: 0.5706 - val_acc: 0.8277
# Epoch 44/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3709 - acc: 0.8739 - val_loss: 0.5670 - val_acc: 0.8210
# Epoch 45/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3642 - acc: 0.8768 - val_loss: 0.5816 - val_acc: 0.8228
# Epoch 46/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3673 - acc: 0.8762 - val_loss: 0.5593 - val_acc: 0.8269
# Epoch 47/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3537 - acc: 0.8810 - val_loss: 0.5564 - val_acc: 0.8285
# Epoch 48/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3505 - acc: 0.8820 - val_loss: 0.5630 - val_acc: 0.8237
# Epoch 49/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3566 - acc: 0.8799 - val_loss: 0.5842 - val_acc: 0.8182
# Epoch 50/50
# 390/390 [==============================] - 9s 24ms/step - loss: 0.3506 - acc: 0.8821 - val_loss: 0.5730 - val_acc: 0.8268
# Model took 451.64 seconds to train
# Accuracy on test data is: 82.68

# %%
#model 2

# Define the model
model = Sequential()

#convolution layer 1
model.add(Convolution2D(32, 3, 3, border_mode='same', input_shape=(32, 32, 3)))    ## 32x32  ## 3
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.20))

#convolution layer 2
model.add(Convolution2D(32, 3, 3, border_mode='same'))    ## 32x32  ## 5
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.20))

#convolution layer 3
model.add(Convolution2D(32, 3, 3, border_mode='same'))    ## 32x32  ## 7
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.20))

#transition layer
model.add(Convolution2D(16, 1, 1, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) # 16x16

#convolution layer 4
model.add(Convolution2D(64, 3, 3, border_mode='same'))    ## 16x16  ## 14
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.20))

#convolution layer 5
model.add(Convolution2D(64, 3, 3, border_mode='same'))    ## 16x16  ## 16
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.20))

#convolution layer 6
model.add(Convolution2D(64, 3, 3, border_mode='same'))    ## 16x16  ## 18
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.20))

#transition layer
model.add(Convolution2D(32, 1, 1, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) # 8x8    ## 24   

#convolution layer 5
model.add(Convolution2D(128, 3, 3, border_mode='same'))    ## 8x8  ## 36
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.20))

#convolution layer 6
model.add(Convolution2D(128, 3, 3, border_mode='same'))    ## 8x8x128  ## 38
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.20))

model.add(Convolution2D(64, 1, 1, activation='relu'))  #8x8x64   

model.add(Convolution2D(10,8,8))    ## 1x1x10    ##rf --


model.add(Flatten())

model.add(Activation(activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same")`
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (1, 1), activation="relu")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:54: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:59: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 1), activation="relu")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8))`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_37 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_35 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_36 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_37 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 32, 32, 16)        528
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 16, 16, 64)        9280
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_38 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_39 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_40 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 8, 8, 128)         36992
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_41 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_42 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 8, 8, 64)          8256
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 1, 1, 10)          40970
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_43 (Activation)   (None, 10)                0
# =================================================================
# Total params: 341,114
# Trainable params: 340,026
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# Epoch 1/100
#   3/390 [..............................] - ETA: 21s - loss: 1.8961 - acc: 0.2812
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=100)`
#   """
# 390/390 [==============================] - 16s 42ms/step - loss: 1.4843 - acc: 0.4522 - val_loss: 1.6792 - val_acc: 0.4048
# Epoch 2/100
# 390/390 [==============================] - 16s 41ms/step - loss: 1.1087 - acc: 0.6029 - val_loss: 1.1446 - val_acc: 0.5937
# Epoch 3/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.9015 - acc: 0.6811 - val_loss: 1.1561 - val_acc: 0.6189
# Epoch 4/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.7839 - acc: 0.7260 - val_loss: 0.8360 - val_acc: 0.7100
# Epoch 5/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.7101 - acc: 0.7510 - val_loss: 0.8901 - val_acc: 0.6982
# Epoch 6/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.6503 - acc: 0.7732 - val_loss: 1.2635 - val_acc: 0.5906
# Epoch 7/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.6061 - acc: 0.7872 - val_loss: 0.7231 - val_acc: 0.7522
# Epoch 8/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.5687 - acc: 0.8005 - val_loss: 0.8573 - val_acc: 0.6987
# Epoch 9/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.5385 - acc: 0.8086 - val_loss: 0.9031 - val_acc: 0.7037
# Epoch 10/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.5118 - acc: 0.8185 - val_loss: 0.8229 - val_acc: 0.7337
# Epoch 11/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.4876 - acc: 0.8302 - val_loss: 0.7101 - val_acc: 0.7646
# Epoch 12/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.4638 - acc: 0.8353 - val_loss: 0.6452 - val_acc: 0.7793
# Epoch 13/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.4451 - acc: 0.8428 - val_loss: 0.7286 - val_acc: 0.7625
# Epoch 14/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.4287 - acc: 0.8478 - val_loss: 0.7385 - val_acc: 0.7657
# Epoch 15/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.4099 - acc: 0.8531 - val_loss: 0.6031 - val_acc: 0.7959
# Epoch 16/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.4003 - acc: 0.8574 - val_loss: 0.6855 - val_acc: 0.7815
# Epoch 17/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.3805 - acc: 0.8638 - val_loss: 0.6452 - val_acc: 0.7874
# Epoch 18/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.3711 - acc: 0.8686 - val_loss: 0.5876 - val_acc: 0.8065
# Epoch 19/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.3578 - acc: 0.8719 - val_loss: 0.6488 - val_acc: 0.7848
# Epoch 20/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.3477 - acc: 0.8763 - val_loss: 0.5894 - val_acc: 0.8041
# Epoch 21/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.3368 - acc: 0.8796 - val_loss: 0.5568 - val_acc: 0.8201
# Epoch 22/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.3327 - acc: 0.8806 - val_loss: 0.6388 - val_acc: 0.7936
# Epoch 23/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.3210 - acc: 0.8844 - val_loss: 0.6423 - val_acc: 0.7946
# Epoch 24/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.3103 - acc: 0.8892 - val_loss: 0.6123 - val_acc: 0.8000
# Epoch 25/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.3005 - acc: 0.8915 - val_loss: 0.6714 - val_acc: 0.7935
# Epoch 26/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.2939 - acc: 0.8951 - val_loss: 0.6635 - val_acc: 0.7894
# Epoch 27/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.2871 - acc: 0.8966 - val_loss: 0.7011 - val_acc: 0.7761
# Epoch 28/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.2870 - acc: 0.8975 - val_loss: 0.6608 - val_acc: 0.7935
# Epoch 29/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.2775 - acc: 0.9011 - val_loss: 0.6244 - val_acc: 0.8028
# Epoch 30/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.2667 - acc: 0.9042 - val_loss: 0.5526 - val_acc: 0.8237
# Epoch 31/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2651 - acc: 0.9049 - val_loss: 0.6259 - val_acc: 0.8034
# Epoch 32/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2612 - acc: 0.9057 - val_loss: 0.5967 - val_acc: 0.8117
# Epoch 33/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2511 - acc: 0.9099 - val_loss: 0.6360 - val_acc: 0.8054
# Epoch 34/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.2463 - acc: 0.9101 - val_loss: 0.7800 - val_acc: 0.7648
# Epoch 35/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.2410 - acc: 0.9132 - val_loss: 0.6455 - val_acc: 0.8065
# Epoch 36/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.2351 - acc: 0.9160 - val_loss: 0.6288 - val_acc: 0.8130
# Epoch 37/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2332 - acc: 0.9156 - val_loss: 0.6787 - val_acc: 0.8011
# Epoch 38/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2293 - acc: 0.9165 - val_loss: 0.5680 - val_acc: 0.8306
# Epoch 39/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.2272 - acc: 0.9176 - val_loss: 0.6816 - val_acc: 0.7978
# Epoch 40/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2237 - acc: 0.9191 - val_loss: 0.6070 - val_acc: 0.8176
# Epoch 41/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2139 - acc: 0.9230 - val_loss: 0.6071 - val_acc: 0.8218
# Epoch 42/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2132 - acc: 0.9224 - val_loss: 0.6872 - val_acc: 0.8023
# Epoch 43/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.2084 - acc: 0.9246 - val_loss: 0.6879 - val_acc: 0.8026
# Epoch 44/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2123 - acc: 0.9245 - val_loss: 0.7043 - val_acc: 0.7895
# Epoch 45/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.2038 - acc: 0.9266 - val_loss: 0.6241 - val_acc: 0.8283
# Epoch 46/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2038 - acc: 0.9264 - val_loss: 0.5768 - val_acc: 0.8293
# Epoch 47/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2019 - acc: 0.9279 - val_loss: 0.6459 - val_acc: 0.8179
# Epoch 48/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1956 - acc: 0.9296 - val_loss: 0.6607 - val_acc: 0.8107
# Epoch 49/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1958 - acc: 0.9291 - val_loss: 0.6824 - val_acc: 0.8112
# Epoch 50/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1910 - acc: 0.9302 - val_loss: 0.6250 - val_acc: 0.8198
# Epoch 51/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1872 - acc: 0.9333 - val_loss: 0.6744 - val_acc: 0.8131
# Epoch 52/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1904 - acc: 0.9298 - val_loss: 0.6421 - val_acc: 0.8190
# Epoch 53/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1744 - acc: 0.9372 - val_loss: 0.6674 - val_acc: 0.8186
# Epoch 54/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1826 - acc: 0.9331 - val_loss: 0.7344 - val_acc: 0.8067
# Epoch 55/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1783 - acc: 0.9357 - val_loss: 0.6497 - val_acc: 0.8232
# Epoch 56/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1750 - acc: 0.9370 - val_loss: 0.6711 - val_acc: 0.8166
# Epoch 57/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1766 - acc: 0.9358 - val_loss: 0.6336 - val_acc: 0.8300
# Epoch 58/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1754 - acc: 0.9359 - val_loss: 0.6631 - val_acc: 0.8159
# Epoch 59/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1734 - acc: 0.9374 - val_loss: 0.6476 - val_acc: 0.8230
# Epoch 60/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1670 - acc: 0.9390 - val_loss: 0.6687 - val_acc: 0.8227
# Epoch 61/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1718 - acc: 0.9382 - val_loss: 0.6371 - val_acc: 0.8263
# Epoch 62/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1682 - acc: 0.9382 - val_loss: 0.7460 - val_acc: 0.7907
# Epoch 63/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1645 - acc: 0.9404 - val_loss: 0.6277 - val_acc: 0.8303
# Epoch 64/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1651 - acc: 0.9402 - val_loss: 0.6821 - val_acc: 0.8186
# Epoch 65/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1573 - acc: 0.9421 - val_loss: 0.7120 - val_acc: 0.8085
# Epoch 66/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1562 - acc: 0.9427 - val_loss: 0.6421 - val_acc: 0.8300
# Epoch 67/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1564 - acc: 0.9425 - val_loss: 0.6815 - val_acc: 0.8253
# Epoch 68/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1608 - acc: 0.9421 - val_loss: 0.6046 - val_acc: 0.8356
# Epoch 69/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1543 - acc: 0.9448 - val_loss: 0.6421 - val_acc: 0.8273
# Epoch 70/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1515 - acc: 0.9454 - val_loss: 0.6533 - val_acc: 0.8240
# Epoch 71/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1525 - acc: 0.9453 - val_loss: 0.6224 - val_acc: 0.8357
# Epoch 72/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1555 - acc: 0.9433 - val_loss: 0.6734 - val_acc: 0.8224
# Epoch 73/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1503 - acc: 0.9460 - val_loss: 0.8321 - val_acc: 0.7873
# Epoch 74/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1503 - acc: 0.9443 - val_loss: 0.7198 - val_acc: 0.8136
# Epoch 75/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1465 - acc: 0.9466 - val_loss: 0.6434 - val_acc: 0.8320
# Epoch 76/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1504 - acc: 0.9461 - val_loss: 0.6400 - val_acc: 0.8301
# Epoch 77/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1437 - acc: 0.9476 - val_loss: 0.6557 - val_acc: 0.8222
# Epoch 78/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1416 - acc: 0.9489 - val_loss: 0.7032 - val_acc: 0.8143
# Epoch 79/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1410 - acc: 0.9483 - val_loss: 0.6557 - val_acc: 0.8325
# Epoch 80/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1403 - acc: 0.9488 - val_loss: 0.7092 - val_acc: 0.8156
# Epoch 81/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1370 - acc: 0.9505 - val_loss: 0.7666 - val_acc: 0.8095
# Epoch 82/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1434 - acc: 0.9481 - val_loss: 0.6428 - val_acc: 0.8334
# Epoch 83/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1401 - acc: 0.9496 - val_loss: 0.6310 - val_acc: 0.8326
# Epoch 84/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1349 - acc: 0.9515 - val_loss: 0.6553 - val_acc: 0.8337
# Epoch 85/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1361 - acc: 0.9496 - val_loss: 0.6779 - val_acc: 0.8281
# Epoch 86/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1348 - acc: 0.9518 - val_loss: 0.6804 - val_acc: 0.8253
# Epoch 87/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1306 - acc: 0.9524 - val_loss: 0.6960 - val_acc: 0.8188
# Epoch 88/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1319 - acc: 0.9522 - val_loss: 0.7194 - val_acc: 0.8230
# Epoch 89/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1376 - acc: 0.9502 - val_loss: 0.6820 - val_acc: 0.8249
# Epoch 90/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1312 - acc: 0.9520 - val_loss: 0.6677 - val_acc: 0.8252
# Epoch 91/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1315 - acc: 0.9534 - val_loss: 0.6332 - val_acc: 0.8397
# Epoch 92/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1302 - acc: 0.9541 - val_loss: 0.6494 - val_acc: 0.8341
# Epoch 93/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1276 - acc: 0.9544 - val_loss: 0.7431 - val_acc: 0.8184
# Epoch 94/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1287 - acc: 0.9547 - val_loss: 0.7094 - val_acc: 0.8236
# Epoch 95/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1241 - acc: 0.9548 - val_loss: 0.6706 - val_acc: 0.8356
# Epoch 96/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1315 - acc: 0.9538 - val_loss: 0.7162 - val_acc: 0.8253
# Epoch 97/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1291 - acc: 0.9531 - val_loss: 0.6983 - val_acc: 0.8283
# Epoch 98/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1307 - acc: 0.9525 - val_loss: 0.6902 - val_acc: 0.8283
# Epoch 99/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1248 - acc: 0.9542 - val_loss: 0.6539 - val_acc: 0.8307
# Epoch 100/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.1252 - acc: 0.9559 - val_loss: 0.6397 - val_acc: 0.8386
# Model took 1614.25 seconds to train
# Accuracy on test data is: 83.86

# %% [markdown]
# #getting 83.86 validation accuracy
